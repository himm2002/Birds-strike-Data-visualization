# %% [markdown]
# # Data Visualization of Birds Strike By Aircrafts B/W 2000-2011

# %% [markdown]
# Objective - Bird strike is defined as a collision between a bird and aircraft which is in flight or a take-off or landing-roll.It is common and
# significant threat to aircraft safety.So we are going to do the analysis for the research questions as well as finding the key factors responsible
# for the increment in the bird strikes and suggestions to reduce the incidents

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
from pandas import DataFrame,Series
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing Database

# %%
os.chdir("C://Users//Administrator//OneDrive//Desktop//Birds Strike Analysis")

# %%
df_1 = pd.read_csv("Bird Strikes data.csv")

# %%
df_1.head()
# Out:
#    Record ID Aircraft: Type                Airport: Name Altitude bin  \
# 0     202152       Airplane                 LAGUARDIA NY    > 1000 ft
# 1     208159       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2     207601       Airplane            LAKEFRONT AIRPORT    < 1000 ft
# 3     215953       Airplane          SEATTLE-TACOMA INTL    < 1000 ft
# 4     219878       Airplane                 NORFOLK INTL    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
# 2                C-500                Over 100
# 3            B-737-400                Over 100
# 4         CL-RJ100/200                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight  FlightDate  \
# 0                             859         Engine Shut Down  23-11-2000
# 1                             424                      NaN  25-07-2001
# 2                             261                      NaN  14-09-2001
# 3                             806    Precautionary Landing  05-09-2002
# 4                             942                      NaN  23-06-2003
#
#   Effect: Indicated Damage  ... Wildlife: Size Conditions: Sky  \
# 0            Caused damage  ...         Medium        No Cloud
# 1            Caused damage  ...          Small      Some Cloud
# 2                No damage  ...          Small        No Cloud
# 3                No damage  ...          Small      Some Cloud
# 4                No damage  ...          Small        No Cloud
#
#        Wildlife: Species Pilot warned of birds or wildlife? Cost: Total $  \
# 0  Unknown bird - medium                                0.0         30736
# 1            Rock pigeon                                1.0             0
# 2      European starling                                0.0             0
# 3      European starling                                1.0             0
# 4      European starling                                0.0             0
#
#    Feet above ground  Number of people injured Is Aircraft Large?  \
# 0             1500.0                         0                1.0
# 1                0.0                         0                0.0
# 2               50.0                         0                0.0
# 3               50.0                         0                1.0
# 4               50.0                         0                0.0
#
#   Extra Altitude Bins Wildlife: Number struck Extra Bins
# 0              2000.0                             1000.0
# 1              1000.0                             1000.0
# 2              1000.0                             1000.0
# 3              1000.0                             1000.0
# 4              1000.0                             1000.0
#
# [5 rows x 28 columns]

# %%
df_1.tail()
# Out:
#        Record ID Aircraft: Type                    Airport: Name Altitude bin  \
# 25553     321151       Airplane                REDDING MUNICIPAL    > 1000 ft
# 25554     319677       Airplane                     ORLANDO INTL    < 1000 ft
# 25555     319680            NaN                              NaN          NaN
# 25556     319679       Airplane  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft
# 25557     319593       Airplane     ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft
#
#       Aircraft: Make/Model Wildlife: Number struck  \
# 25553              EMB-120                       1
# 25554                A-321                       1
# 25555               EC-135                     NaN
# 25556            B-757-200                       1
# 25557            B-737-400                       1
#
#        Wildlife: Number Struck Actual Effect: Impact to flight  FlightDate  \
# 25553                               1                      NaN  30-12-2011
# 25554                               1                      NaN  30-12-2011
# 25555                               1                      NaN         NaN
# 25556                               1                      NaN  31-12-2011
# 25557                               1                      NaN  31-12-2011
#
#       Effect: Indicated Damage  ... Wildlife: Size Conditions: Sky  \
# 25553                No damage  ...          Large        Overcast
# 25554                No damage  ...          Small      Some Cloud
# 25555                No damage  ...            NaN        No Cloud
# 25556                No damage  ...         Medium      Some Cloud
# 25557            Caused damage  ...         Medium        No Cloud
#
#            Wildlife: Species Pilot warned of birds or wildlife? Cost: Total $  \
# 25553   Unknown bird - large                                0.0             0
# 25554           Tree swallow                                1.0             0
# 25555   Unknown bird - small                                NaN             0
# 25556  Unknown bird - medium                                1.0             0
# 25557        Red-tailed hawk                                0.0             0
#
#        Feet above ground  Number of people injured Is Aircraft Large?  \
# 25553             1500.0                         0                0.0
# 25554                0.0                         0                0.0
# 25555                NaN                         0                NaN
# 25556                0.0                         0                1.0
# 25557                0.0                         0                1.0
#
#       Extra Altitude Bins Wildlife: Number struck Extra Bins
# 25553              2000.0                                NaN
# 25554              1000.0                                NaN
# 25555                 NaN                                NaN
# 25556              1000.0                                NaN
# 25557              1000.0                                NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# # Data Cleaning and Transformation

# %%
shape_1 = df_1.shape
print("Number of rows are {} and columns are {}".format(shape_1[0],shape_1[1]))
# Out:
# Number of rows are 25558 and columns are 28

# %%
# removing unwanted columns

# %%
df_1.columns
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Aircraft: Make/Model', 'Wildlife: Number struck',
#        'Wildlife: Number Struck Actual', 'Effect: Impact to flight',
#        'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Number of engines?', 'Aircraft: Airline/Operator',
#        'Origin State', 'When: Phase of flight', 'Conditions: Precipitation',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Remarks', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $',
#        'Feet above ground', 'Number of people injured', 'Is Aircraft Large?',
#        'Extra Altitude Bins', 'Wildlife: Number struck Extra Bins'],
#       dtype='object')

# %%
df_1.drop(columns = ["Aircraft: Make/Model","Aircraft: Number of engines?","Remarks"],axis=1,inplace=True)

# %%
# checking the null values

# %%
df_1.isnull().sum()
# Out:
# Record ID                                      0
# Aircraft: Type                               129
# Airport: Name                                129
# Altitude bin                                 129
# Wildlife: Number struck                      129
# Wildlife: Number Struck Actual                 0
# Effect: Impact to flight                   23480
# FlightDate                                   129
# Effect: Indicated Damage                       0
# Aircraft: Airline/Operator                   129
# Origin State                                 449
# When: Phase of flight                        129
# Conditions: Precipitation                  23543
# Remains of wildlife collected?                 0
# Remains of wildlife sent to Smithsonian        0
# Wildlife: Size                               129
# Conditions: Sky                                0
# Wildlife: Species                              0
# Pilot warned of birds or wildlife?           129
# Cost: Total $                                  0
# Feet above ground                            129
# Number of people injured                       0
# Is Aircraft Large?                           129
# Extra Altitude Bins                          129
# Wildlife: Number struck Extra Bins         20919
# dtype: int64

# %% [markdown]
# Here are the some columns which are having almost 75% null values present in it so we remove that columns which is not needed for our analysis

# %%
df_1.drop(columns = ["Wildlife: Number struck Extra Bins","Conditions: Precipitation"],axis=1,inplace=True)

# %%
df_1["Effect: Impact to flight"].unique()
# Out:
# array(['Engine Shut Down', nan, 'Precautionary Landing', 'Other',
#        'Aborted Take-off'], dtype=object)

# %%
df_1["Effect: Impact to flight"]= df_1["Effect: Impact to flight"].replace(np.nan,"No Impact")

# %%
df_1.isnull().sum()
# Out:
# Record ID                                    0
# Aircraft: Type                             129
# Airport: Name                              129
# Altitude bin                               129
# Wildlife: Number struck                    129
# Wildlife: Number Struck Actual               0
# Effect: Impact to flight                     0
# FlightDate                                 129
# Effect: Indicated Damage                     0
# Aircraft: Airline/Operator                 129
# Origin State                               449
# When: Phase of flight                      129
# Remains of wildlife collected?               0
# Remains of wildlife sent to Smithsonian      0
# Wildlife: Size                             129
# Conditions: Sky                              0
# Wildlife: Species                            0
# Pilot warned of birds or wildlife?         129
# Cost: Total $                                0
# Feet above ground                          129
# Number of people injured                     0
# Is Aircraft Large?                         129
# Extra Altitude Bins                        129
# dtype: int64

# %% [markdown]
# And Now the remaining null row values is going to remove

# %%
df_1 = df_1.dropna(axis = 0, how = "any")

# %%
# changing the data type of flight date to date

# %%
df_1["FlightDate"] = pd.to_datetime(df_1["FlightDate"],format="%d-%m-%Y")

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24980 entries, 0 to 25557
# Data columns (total 23 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Record ID                                24980 non-null  int64
#  1   Aircraft: Type                           24980 non-null  object
#  2   Airport: Name                            24980 non-null  object
#  3   Altitude bin                             24980 non-null  object
#  4   Wildlife: Number struck                  24980 non-null  object
#  5   Wildlife: Number Struck Actual           24980 non-null  int64
#  6   Effect: Impact to flight                 24980 non-null  object
#  7   FlightDate                               24980 non-null  datetime64[ns]
#  8   Effect: Indicated Damage                 24980 non-null  object
#  9   Aircraft: Airline/Operator               24980 non-null  object
#  10  Origin State                             24980 non-null  object
#  11  When: Phase of flight                    24980 non-null  object
#  12  Remains of wildlife collected?           24980 non-null  bool
#  13  Remains of wildlife sent to Smithsonian  24980 non-null  bool
#  14  Wildlife: Size                           24980 non-null  object
#  15  Conditions: Sky                          24980 non-null  object
#  16  Wildlife: Species                        24980 non-null  object
#  17  Pilot warned of birds or wildlife?       24980 non-null  float64
#  18  Cost: Total $                            24980 non-null  int64
#  19  Feet above ground                        24980 non-null  float64
#  20  Number of people injured                 24980 non-null  int64
#  21  Is Aircraft Large?                       24980 non-null  float64
#  22  Extra Altitude Bins                      24980 non-null  float64
# dtypes: bool(2), datetime64[ns](1), float64(4), int64(4), object(12)
# memory usage: 4.2+ MB

# %% [markdown]
# # Case Studies Data Visualization And Analysis

# %%
df_1.describe(include="object")
# Out:
#        Aircraft: Type                Airport: Name Altitude bin  \
# count           24980                        24980        24980
# unique              1                          983            2
# top          Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# freq            24980                          803        20185
#
#        Wildlife: Number struck Effect: Impact to flight  \
# count                    24980                    24980
# unique                       4                        5
# top                          1                No Impact
# freq                     20401                    22923
#
#        Effect: Indicated Damage Aircraft: Airline/Operator Origin State  \
# count                     24980                      24980        24980
# unique                        2                        289           60
# top                   No damage         SOUTHWEST AIRLINES   California
# freq                      22572                       4628         2499
#
#        When: Phase of flight Wildlife: Size Conditions: Sky  \
# count                  24980          24980           24980
# unique                     7              3               3
# top                 Approach          Small        No Cloud
# freq                   10227          17139           12325
#
#            Wildlife: Species
# count                  24980
# unique                   342
# top     Unknown bird - small
# freq                   10180

# %% [markdown]
# Here we can see the top values for the categorical columns which can be used as a assumption for hypothesis testing

# %%
# statistical analysis

# %%
df_1["Cost: Total $"]= df_1["Cost: Total $"].astype(int)

# %%
df_1.describe()
# Out:
#            Record ID  Wildlife: Number Struck Actual  \
# count   24980.000000                    24980.000000
# mean   253711.126101                        2.692074
# min      1195.000000                        1.000000
# 25%    225689.500000                        1.000000
# 50%    248556.000000                        1.000000
# 75%    268974.250000                        1.000000
# max    321909.000000                      942.000000
# std     38486.726793                       12.474254
#
#                           FlightDate  Pilot warned of birds or wildlife?  \
# count                          24980                        24980.000000
# mean   2007-01-20 14:55:11.192954368                            0.433227
# min              2000-01-02 00:00:00                            0.000000
# 25%              2004-06-14 00:00:00                            0.000000
# 50%              2007-07-27 12:00:00                            0.000000
# 75%              2009-10-31 00:00:00                            1.000000
# max              2011-12-31 00:00:00                            1.000000
# std                              NaN                            0.495531
#
#        Cost: Total $  Feet above ground  Number of people injured  \
# count   2.498000e+04       24980.000000              24980.000000
# mean    5.489909e+03         797.129944                  0.000841
# min     0.000000e+00           0.000000                  0.000000
# 25%     0.000000e+00           0.000000                  0.000000
# 50%     0.000000e+00          50.000000                  0.000000
# 75%     0.000000e+00         700.000000                  0.000000
# max     1.239775e+07       18000.000000                  6.000000
# std     1.226273e+05        1730.327167                  0.047762
#
#        Is Aircraft Large?  Extra Altitude Bins
# count        24980.000000         24980.000000
# mean             0.327462          1886.068855
# min              0.000000          1000.000000
# 25%              0.000000          1000.000000
# 50%              0.000000          1000.000000
# 75%              1.000000          1000.000000
# max              1.000000         18000.000000
# std              0.469297          3148.929868

# %% [markdown]
# # Outliers detection for Altitude column

# %%
sns.boxplot(data = df_1, x= "Feet above ground")
# Out:
# <Axes: xlabel='Feet above ground'>

# %% [markdown]
# Here it is that we cannot remove the outliers becuase if we remove that like removing 12000- 18000 altitude values it will affect our analysis

# %% [markdown]
# # Visuals Depicting the number of bird strikes

# %%
df_1.columns
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Wildlife: Number struck', 'Wildlife: Number Struck Actual',
#        'Effect: Impact to flight', 'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Airline/Operator', 'Origin State', 'When: Phase of flight',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $',
#        'Feet above ground', 'Number of people injured', 'Is Aircraft Large?',
#        'Extra Altitude Bins'],
#       dtype='object')

# %%
birds_trend = df_1.groupby(["FlightDate","Altitude bin"],as_index=False).agg({"Wildlife: Number Struck Actual":"sum"})

# %%
birds_trend
# Out:
#      FlightDate Altitude bin  Wildlife: Number Struck Actual
# 0    2000-01-02    < 1000 ft                              56
# 1    2000-01-02    > 1000 ft                               1
# 2    2000-01-03    < 1000 ft                               1
# 3    2000-01-03    > 1000 ft                               1
# 4    2000-01-04    < 1000 ft                               3
# ...         ...          ...                             ...
# 6493 2011-12-28    > 1000 ft                               7
# 6494 2011-12-29    < 1000 ft                              20
# 6495 2011-12-30    < 1000 ft                               8
# 6496 2011-12-30    > 1000 ft                               1
# 6497 2011-12-31    < 1000 ft                               8
#
# [6498 rows x 3 columns]

# %% [markdown]
# we are having lots of trend data as it is from 2000 to 2012 that makes analysis also tough so we divided the trend into two parts

# %%
birds_trend_1 = birds_trend[(birds_trend["FlightDate"] >= "2000") & (birds_trend["FlightDate"] <= "2006")]

# %%
birds_trend_2 =  birds_trend[(birds_trend["FlightDate"] > "2006") & (birds_trend["FlightDate"] <= "2012")]

# %%
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
plt.figure(figsize=(20,9))
sns.lineplot(data = birds_trend_1, x="FlightDate",y= "Wildlife: Number Struck Actual",hue="Altitude bin",palette="CMRmap")
plt.xlabel("Timeline",fontsize=20)
plt.ylabel("Number of Birds Strikes",fontsize=20)
plt.title("Number of Bird Strikes From 2000-2006",fontsize =25)
plt.show()

# %% [markdown]
# So here we can analyze that if the aircraft altitude is < 1000 then the birds strikes occured more as compare to > 1000 altitude their is only one
# spike around 2000-2001 where if the altitude > 1000 then the strike occured

# %%
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
plt.figure(figsize=(20,9))
sns.lineplot(data = birds_trend_2, x="FlightDate",y= "Wildlife: Number Struck Actual",hue="Altitude bin",palette="CMRmap")
plt.xlabel("Timeline",fontsize=20)
plt.ylabel("Number of Birds Strikes",fontsize=20)
plt.title("Number of Bird Strikes From 2006-2012",fontsize =25)
plt.show()

# %% [markdown]
# Same here for the date between 2006 to 2012 but one thing we can see the birds strikes having altitude < 1000 that their is a pattern in the trend
# line as starting of the year is having constant line and at the middle of the year their is constant increase in the birds strike and them decrease again we can see in
# the each year comparison here so there might be a chance that climatic changes would be the reason for the same at the end of year

# %% [markdown]
# # Hypothesis- Altitude effect on Bird Strikes

# %% [markdown]
# Hypothesis - Birds strike are most likely occur during the take-offs,initial climb, approach and lanading phases that means lesser altitude higher
# bird strikes and higher altitude lesser bird strikes

# %%
df_1.columns
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Wildlife: Number struck', 'Wildlife: Number Struck Actual',
#        'Effect: Impact to flight', 'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Airline/Operator', 'Origin State', 'When: Phase of flight',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $',
#        'Feet above ground', 'Number of people injured', 'Is Aircraft Large?',
#        'Extra Altitude Bins'],
#       dtype='object')

# %%
df_1.rename(columns = {"Feet above ground":"Altitude"},inplace=True)

# %%
data_3 = df_1[(df_1["Wildlife: Number Struck Actual"] > 10)]

# %%
plt.figure(figsize = (10,5))
sizes = df_1["Wildlife: Number Struck Actual"]
sns.scatterplot(data = data_3,x="Altitude",y="Wildlife: Number Struck Actual",hue="Altitude bin",size= sizes,sizes=(40,80))
plt.title("Altitude and Birds Strike Relationship",fontsize=20)
plt.ylabel("Number of Birds strucks")
plt.show()

# %%
ax_1= sns.barplot(data= df_1,x="Altitude bin",y="Wildlife: Number Struck Actual",estimator="sum",ci=None,palette="OrRd",width=0.6)
for x in ax_1.containers:
    ax_1.bar_label(x,fontsize=15)
plt.title("Birds strike count By Altitude",fontsize=20)
plt.ylabel("Number of bird strikes")
plt.show()

# %% [markdown]
# As per the first graph we can see the distribution of data as many data is clustred where the altitude is less than 1000 as altitude is increasing less
# data is distributed is there so increasing altitude having negative impact on the birds strike and second bar chart shows the actual number of birds
# strike for when altitude < 1000 is 58538 and when altitude > 1000 is 8710 so our hypothesis is correct that mostly birds strike occur at the low
# altitude when aircraft is in take-off,initial climb, approach and landing phases

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\administrator\anaconda3\lib\site-packages (10.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Yearly Analysis for the Bird Strike in US

# %%
df_1["Year"] = pd.DatetimeIndex(df_1["FlightDate"]).year

# %%
df_1["Year"].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2006, 2004, 2005, 2007, 2008, 2009, 2010,
#        2011])

# %%
new_data = df_1.groupby(["Year"],as_index=False).agg({"Wildlife: Number Struck Actual":"sum"})

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=new_data,x="Year",y="Wildlife: Number Struck Actual",ci=30,marker="o",color="k",alpha=0.8)
plt.ylabel("Number of bird strikes",fontsize=13)
plt.xlabel("Years",fontsize=13)
plt.title("Birds Strike in the US Yearly Analysis",fontsize=16)
# label points on the plot
for x, y in zip(new_data["Year"], new_data["Wildlife: Number Struck Actual"]):
 plt.text(x = x, 
 y = y-150,
 s = "{:.0f}".format(y), 
 color = "purple")

# %% [markdown]
# This whole data is taken from US so that's why take the whole dataset

# %% [markdown]
# As per the above yearly trend line as the years increasing the number of bird strikes are also increased where highest recorded in 2010 with 7545
# incidents and lowest in the 2004 with 4321 incidents however their is dip in the incidents from 2010 to 2011 but not a big impact.The reason behind
# the strikes increasing as the time increases is might be the increasing number of aircrafts as demand is increasing because of the population

# %% [markdown]
# # Airlines Bird Strike Analysis

# %%
df_1.columns
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Wildlife: Number struck', 'Wildlife: Number Struck Actual',
#        'Effect: Impact to flight', 'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Airline/Operator', 'Origin State', 'When: Phase of flight',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $', 'Altitude',
#        'Number of people injured', 'Is Aircraft Large?', 'Extra Altitude Bins',
#        'Year'],
#       dtype='object')

# %%
data_2 = df_1.groupby(["Aircraft: Airline/Operator"],as_index=False).agg({"Wildlife: Number Struck Actual":"sum"}).sort_values(by="Wildlife: Number Struck Actual",
ascending=False).head(10)

# %%
data_2= data_2.reset_index(drop=True)

# %%
data_2
# Out:
#   Aircraft: Airline/Operator  Wildlife: Number Struck Actual
# 0                   BUSINESS                            9315
# 1         SOUTHWEST AIRLINES                            9208
# 2          AMERICAN AIRLINES                            5248
# 3                 US AIRWAYS                            4596
# 4            DELTA AIR LINES                            3767
# 5    AMERICAN EAGLE AIRLINES                            2733
# 6            COMAIR AIRLINES                            1985
# 7            UNITED AIRLINES                            1930
# 8           SKYWEST AIRLINES                            1920
# 9            ALASKA AIRLINES                            1531

# %%
plt.figure(figsize=(15,7))
ax_1 =  sns.barplot(data=data_2,y="Aircraft: Airline/Operator",x="Wildlife: Number Struck Actual",estimator="sum",palette="cividis")
for x in ax_1.containers:
    ax_1.bar_label(x,fontsize=13)
plt.ylabel("Airline Operator",fontsize=15)
plt.xlabel("Number of birds strike",fontsize=15)
plt.title("Top 10 US Airlines Encountered Birds Strike",fontsize=20)
plt.show()

# %% [markdown]
# # Birds Strike Distribution

# %%
plt.figure(figsize=(15,5))

sns.displot(data=df_1,x="Altitude",color="g",kde=True)
plt.xlabel("Altitude Bins")
plt.title("Altitude Distribution")
plt.show()

# %% [markdown]
# Here we can see after after 5000 altitude the density of altitude is very low so for more clarified distribution we take only altitude bins upto 5000

# %%
data_4 = df_1[(df_1["Altitude"] <= 5000) & (df_1["Altitude"]>0)]

# %%
plt.figure(figsize=(20,5))

sns.displot(data=data_4,x="Altitude",color="g",kde=True,hue="When: Phase of flight")
plt.xlabel("Altitude Bins")
plt.title("Altitude Distribution By Phase of flight",fontsize=20)
plt.show()

# %% [markdown]
# Here we can see two things first greater number of values for altitude < 1000 so birds striking most commonly happening in < 1000 altitude and second
# when the flight is approaching it encountered more birds strike and on the second when flight is about in its Climbing phase so that truly proves the
# hypothesis as well

# %%
df_1.columns
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Wildlife: Number struck', 'Wildlife: Number Struck Actual',
#        'Effect: Impact to flight', 'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Airline/Operator', 'Origin State', 'When: Phase of flight',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $', 'Altitude',
#        'Number of people injured', 'Is Aircraft Large?', 'Extra Altitude Bins',
#        'Year'],
#       dtype='object')

# %% [markdown]
# # Airports with most incidents of birds strike- Top 50

# %%
new_df = df_1.groupby(["Airport: Name"],as_index=False).agg({"Wildlife: Number Struck Actual":"sum"}).sort_values(by="Wildlife: Number Struck Actual",
ascending=False)

# %%
new_df = new_df.head(50)

# %%
new_df.reset_index(drop=True,inplace=True)

# %%
new_df.rename(columns = {"Wildlife: Number Struck Actual":"Struck Numbers"},inplace=True)
new_df
# Out:
#                              Airport: Name  Struck Numbers
# 0              DALLAS/FORT WORTH INTL ARPT            2933
# 1                          SACRAMENTO INTL            1856
# 2                             LAGUARDIA NY            1579
# 3                        PHILADELPHIA INTL            1396
# 4                      SALT LAKE CITY INTL            1376
# 5                  SAN FRANCISCO INTL ARPT            1210
# 6                      JOHN F KENNEDY INTL            1207
# 7                      SEATTLE-TACOMA INTL            1181
# 8                             NORFOLK INTL            1119
# 9                      BALTIMORE WASH INTL            1027
# 10                          NASHVILLE INTL            1003
# 11                              LOGAN INTL             962
# 12                        KANSAS CITY INTL             921
# 13             CHARLOTTE/DOUGLAS INTL ARPT             917
# 14  CINCINNATI/NORTHERN KENTUCKY INTL ARPT             915
# 15                    LOUISVILLE INTL ARPT             914
# 16                            ATLANTA INTL             897
# 17                NEWARK LIBERTY INTL ARPT             880
# 18                            ORLANDO INTL             855
# 19                     DENVER INTL AIRPORT             845
# 20             WASHINGTON DULLES INTL ARPT             826
# 21                      METRO OAKLAND INTL             775
# 22                CHICAGO O'HARE INTL ARPT             752
# 23             CLEVELAND-HOPKINS INTL ARPT             742
# 24                         HARRISBURG INTL             731
# 25                   LAMBERT-ST LOUIS INTL             659
# 26         DETROIT METRO WAYNE COUNTY ARPT             626
# 27                      GREATER PITTSBURGH             623
# 28                              LIHUE ARPT             613
# 29           BIRMINGHAM-SHUTTLESWORTH INTL             605
# 30                CHICAGO MIDWAY INTL ARPT             578
# 31                         EPPLEY AIRFIELD             571
# 32           RONALD REAGAN WASHINGTON NATL             559
# 33                MINNEAPOLIS-ST PAUL INTL             557
# 34                        LOS ANGELES INTL             530
# 35                            MEMPHIS INTL             514
# 36                      PORTLAND INTL (OR)             508
# 37          FORT LAUDERDALE/HOLLYWOOD INTL             481
# 38                    BUFFALO-NIAGARA INTL             474
# 39                          HILO INTL ARPT             466
# 40            GEORGE BUSH INTERCONTINENTAL             460
# 41                       TETERBORO AIRPORT             455
# 42                        NEW ORLEANS INTL             453
# 43                      HONOLULU INTL ARPT             445
# 44                      PORT COLUMBUS INTL             431
# 45                           HOUSTON-HOBBY             421
# 46                   AUSTIN-BERGSTROM INTL             417
# 47                  DALLAS LOVE FIELD ARPT             409
# 48                            BRADLEY INTL             404
# 49                       INDIANAPOLIS INTL             402

# %%
plt.figure(figsize=(20,30))
palette = sns.color_palette("Wistia",n_colors=50)
palette.reverse()
ax_1=sns.barplot(data=new_df,x="Struck Numbers",y="Airport: Name",estimator="sum",palette=palette)
for x in ax_1.containers:
    ax_1.bar_label(x,fontsize=15)
plt.ylabel("Airport Name",fontsize=16)
plt.xlabel("Number of Strikes",fontsize=16)
plt.title("Airports with most incidents of birds strike: Top 50",fontsize=20)
plt.show()

# %% [markdown]
# # Yearly Cost Incurred due to birds strike

# %%
df_1.columns
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Wildlife: Number struck', 'Wildlife: Number Struck Actual',
#        'Effect: Impact to flight', 'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Airline/Operator', 'Origin State', 'When: Phase of flight',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $', 'Altitude',
#        'Number of people injured', 'Is Aircraft Large?', 'Extra Altitude Bins',
#        'Year'],
#       dtype='object')

# %%
new_df_2 = df_1.groupby(["Year","Is Aircraft Large?"],as_index=False).agg({"Cost: Total $":"sum"})

# %%
sns.set_theme()
plt.figure(figsize=(13,5))
sns.lineplot(data=new_df_2,x="Year",y="Cost: Total $",ci=None,marker="o",palette=["red","blue"],hue="Is Aircraft Large?",style="Is Aircraft Large?",legend
=False)
plt.ylabel("Total Cost Incurred ($)",fontsize=13)
plt.xlabel("Years",fontsize=13)
plt.title(" Yearly cost inccured Birds Strike in the US Analysis",fontsize=16)
plt.legend(title='Aircraft Size', loc='upper right', labels=['Smaller Aircraft', 'Bigger Aircraft'])
# label points on the plot
for x, y in zip(new_df_2["Year"], new_df_2["Cost: Total $"]):
 plt.text(x = x, 
 y = y-150,
 s = "{:.0f}".format(y), 
 color = "black")

# %% [markdown]
# From the above line chart we can analyse that cost incurred for the incidents during 2001 is high for smaller aircraft ( $ 18700026) as too high as
# compare to Bigger Aircraft($3249890) as smaller aircrafts might have size issues or less jet engine which make the difficult for the aircraft to
# handle the strike that increases the cost for them but as time progress in the recent year 2011 aircraft larger in size have incurred more cost
# ( $ 9272001) as compare to smaller aircraft( $ 3744722) that is big difference comes which is concerning for the airline operators which we suggest
# to find out the root cause for the increase in cost. As also one thing last three years from 2009 to 2011 the cost incurred on larger aircraft is
# increasing constantly

# %% [markdown]
# # When do birds strike occured the most during phase of flight?

# %%
df_1.columns
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Wildlife: Number struck', 'Wildlife: Number Struck Actual',
#        'Effect: Impact to flight', 'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Airline/Operator', 'Origin State', 'When: Phase of flight',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $', 'Altitude',
#        'Number of people injured', 'Is Aircraft Large?', 'Extra Altitude Bins',
#        'Year'],
#       dtype='object')

# %%
flight_phase_data = df_1.groupby("When: Phase of flight")["Wildlife: Number Struck Actual"].sum()

# %%
flight_phase_data
# Out:
# When: Phase of flight
# Approach        24280
# Climb           13512
# Descent          1276
# Landing Roll    14201
# Parked             13
# Take-off run    13772
# Taxi              194
# Name: Wildlife: Number Struck Actual, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.pie(x=flight_phase_data,labels= flight_phase_data.index,autopct="%.2f",colors=[
        # matplotlib named colors 
        'tomato', 'cornflowerblue', 'gold', 'orchid', 'green', 
        "#77BFE2","brown"],textprops={"fontsize":14,"color":"black"})
plt.title("Birds Strike During Different Phase of Flight",fontsize=20)
plt.show()

# %% [markdown]
# From the above pie chart we can rertieve that most of the incidents occured at Approaching Phase of flight 36% approx and then Landding Roll 21% and
# then climbing and take off run phase contributing to 20% each.Approach phase is between the phase when flight is under 5000 Feet AGL and flight is landed in run way so yes birds and other flying species is at this phase so higher possibility of birds striking occur at this stage But landing roll
# is also contributing 21% that is phase between when plane is landed and exits the run way here we can make the precautions to clean the area for run way for flight to land easily because it is on ground phase so air controller can take some actions here

# %%
df_1.columns
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Wildlife: Number struck', 'Wildlife: Number Struck Actual',
#        'Effect: Impact to flight', 'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Airline/Operator', 'Origin State', 'When: Phase of flight',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $', 'Altitude',
#        'Number of people injured', 'Is Aircraft Large?', 'Extra Altitude Bins',
#        'Year'],
#       dtype='object')

# %% [markdown]
# # Average Altitude At the time of strike for each phase of flight

# %%
new_df_5 = df_1.groupby(["When: Phase of flight"],as_index=False).agg({"Altitude":"mean"})

# %%
new_df_5
# Out:
#   When: Phase of flight     Altitude
# 0              Approach  1002.581891
# 1                 Climb  1197.029638
# 2               Descent  5905.023468
# 3          Landing Roll     0.000000
# 4                Parked     0.000000
# 5          Take-off run     0.103164
# 6                  Taxi     0.000000

# %%
 sns.barplot(data = new_df_5,x="When: Phase of flight",y="Altitude",palette="CMRmap")
# Out:
# <Axes: xlabel='When: Phase of flight', ylabel='Altitude'>

# %% [markdown]
# As Landing Roll, Parked,Take-off run and taxi phase are at the ground level so no altitude would be there so we remove these 3

# %%
new_df_5 = new_df_5[:3]

# %%
new_df_5
# Out:
#   When: Phase of flight     Altitude
# 0              Approach  1002.581891
# 1                 Climb  1197.029638
# 2               Descent  5905.023468

# %%
plt.figure(figsize= (7,5))
ax_1= sns.barplot(data = new_df_5,x="When: Phase of flight",y="Altitude",palette="CMRmap",width=0.4)
for x in ax_1.containers:
    ax_1.bar_label(x)
plt.xlabel("Phase of flight")
plt.ylabel("Average Altitude")
plt.title("Average Altitude at the time of Strike During Each Phase",fontsize=20)
plt.show()

# %% [markdown]
# So from the above graph we can analyse that at the time of approaching phase where the most birds strike occured the average altitude is 1000 Approx
# and during climibing phase 1200 approx and for the descent phase no use of that as around less incidents of birds strike occured during that phase

# %% [markdown]
# # when do most birds strike occured during the timeline

# %%
new_data = new_data.sort_values(by="Wildlife: Number Struck Actual",ascending=False)

# %%
new_data[:1]
# Out:
#     Year  Wildlife: Number Struck Actual
# 10  2010                            7545

# %% [markdown]
# So here we can see that year 2010 having the most number of bird strike incidents occured

# %%
df_1["month"] = pd.DatetimeIndex(df_1["FlightDate"]).month

# %%
df_1["month"].unique()
# Out:
# array([11,  7,  9,  6,  8,  3,  1,  2,  4,  5, 10, 12])

# %%
df_1["month"] = df_1["month"].astype(int)

# %%
monthly_data = df_1.groupby(["month","Year"],as_index=False).agg({"Wildlife: Number Struck Actual":"sum"}).sort_values(by="month")

# %%
monthly_data
# Out:
#      month  Year  Wildlife: Number Struck Actual
# 0        1  2000                             124
# 11       1  2011                             424
# 10       1  2010                             254
# 9        1  2009                             219
# 7        1  2007                             194
# ..     ...   ...                             ...
# 133     12  2001                             184
# 132     12  2000                             106
# 142     12  2010                             342
# 136     12  2004                             202
# 143     12  2011                             320
#
# [144 rows x 3 columns]

# %%
sns.set_theme()
plt.figure(figsize=(13,5)) 
ax=  sns.lineplot(data=monthly_data,x="month",y="Wildlife: Number Struck Actual",marker="o",ci=30,color="cornflowerblue")
plt.title("Number of Birds Strike Across Different Months ( 2000- 2011)",fontsize=20)
plt.xlabel("Month Number")
plt.ylabel("Number of birds strike")
plt.show()

# %% [markdown]
# Here from the above graph we can see that in month July,August,September and October having the highest number of bird strikes that we can retrieve the
# climatic weather conditions change in this season might be due to the weather conditions led birds to stay closer to the area of airport and aircraft
# controlling area or stay on to the ground ..Don't know th exact reason but these 4 months having the most strikes as compare to other months

# %% [markdown]
# # For to see any trend change let's see the same graph for last 4 years

# %%
new_data= df_1[(df_1["FlightDate"] >= "2008") & (df_1["FlightDate"]<= "2011") ]

# %%
new_df = new_data.groupby(["month","Year"]).agg({"Wildlife: Number Struck Actual":"sum"}).sort_values(by="month")

# %%
sns.set_theme()
plt.figure(figsize=(15,5)) 
palette_n = sns.color_palette("CMRmap",n_colors=4)
sns.lineplot(data=new_df,x="month",y="Wildlife: Number Struck Actual",marker="o",ci=40,hue="Year",palette=palette_n)
plt.title("Number of Birds Strike Across Different Months ( 2008- 2011)",fontsize=20)
plt.xlabel("Month Number")
plt.ylabel("Number of birds strike")
plt.show()

# %% [markdown]
# From the above graph we can say that no change in this season increasing in number of birds strike as we can see the all the last
# four years having same increase in that particular season that we see in all the years trendline for month so July August Septemebr and October is the
# rising concerning months to find the root cause for increment

# %% [markdown]
# # Heatmap of Sky Conditions impact on average Bird strike

# %%
pivot_table_1 = pd.pivot_table(data=df_1,index="Conditions: Sky",columns="month",values="Wildlife: Number Struck Actual",aggfunc="mean")

# %%
df_1.columns
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Wildlife: Number struck', 'Wildlife: Number Struck Actual',
#        'Effect: Impact to flight', 'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Airline/Operator', 'Origin State', 'When: Phase of flight',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $', 'Altitude',
#        'Number of people injured', 'Is Aircraft Large?', 'Extra Altitude Bins',
#        'Year', 'month'],
#       dtype='object')

# %%
pivot_table_1
# Out:
# month                  1         2         3         4         5         6   \
# Conditions: Sky
# No Cloud         3.355450  3.643275  2.358804  1.903680  1.610342  3.189218
# Overcast         4.247934  3.769697  3.605042  2.592715  2.494172  2.633333
# Some Cloud       2.465385  2.849206  3.357143  2.092727  1.547558  1.708226
#
# month                  7         8         9         10        11        12
# Conditions: Sky
# No Cloud         2.528413  2.855562  2.275476  2.198788  3.628603  2.778571
# Overcast         2.672330  3.738095  3.076923  3.133065  4.281977  3.897059
# Some Cloud       2.848983  2.876045  3.238938  2.405213  2.847784  2.973941

# %%
plt.figure(figsize=(8,4))
sns.heatmap(pivot_table_1,vmin=1,vmax=4.5,annot=True,cmap="Greens")
plt.title("Conditions Impact in Months on Average Bird Strikes Heatmap",fontsize=20)
plt.xlabel("Month Number")
plt.ylabel("Sky Conditions")
plt.show()

# %% [markdown]
# Above heatmap shows the average bird strikes and its relation between month and sky conditions.We can see Janaury November and december are having
# average bird strikes greater than 3.5 in Overcast conditions and we can also see the the higher color values in overcast sky conditions that means
# overcast sky conditions makes the birds strike more that makes visibility issues for pilot or other air controllers specially in winter season it makes
# more difficult as we see the average value is higher and we can see the vice versa impact as well in some cloud conditions in may and april it is having
# lower average values which means less visibility issues

# %% [markdown]
# # Effect of Birds Strike and Impact on flight

# %%
damage_data = df_1[df_1["Effect: Indicated Damage"] == "Caused damage"]

# %%
plt.figure(figsize=(10,5))
ax_1 = sns.countplot(data = damage_data,x= "Effect: Impact to flight",palette="Paired")
for x in ax_1.containers:
    ax_1.bar_label(x, label_type='edge')
plt.title("Birds Strike impact on flight for Damage Done to Aircraft",fontsize=20)
plt.ylabel("Number of times")
plt.xlabel("Impact On Flight")
plt.show()

# %% [markdown]
# From the above graph the no impact is the most number of times in aircrafts that means no action taken related to the flight and flight run as usual
# it runs when the bird strike incident is happened and next we see the precautionary landing is taken by the air controllers around 533 times this step
# is taken and this number is good or bad both because the 533 times taken landing that leads to delays in flights and the cost as well but this is also
# good step to ensure the safety  of the passengers

# %%
effect_data = df_1.groupby("Effect: Indicated Damage")["Wildlife: Number Struck Actual"].count()

# %%
plt.figure(figsize=(5,5))
myexplode= [0.2,0]
plt.pie(x=effect_data,labels= effect_data.index,autopct="%.2f",colors=[
        # matplotlib named colors 
        'tomato',  'orange'],explode=myexplode,textprops={"color":"black"})
plt.title("Distribution of Effect of Bird Strike on Aircraft ",fontsize=20)
plt.show()

# %% [markdown]
# # Effect of strike at different Altitude

# %%
pivot_table_2 = pd.pivot_table(data=df_1,index="Effect: Indicated Damage",columns="Extra Altitude Bins",values="Wildlife: Number Struck Actual",
                               aggfunc="sum")

# %%
pivot_table_2.rename(columns= { 1000: "<= 1000", 2000:"1000-2000",3000:"2000-3000",4000:"3000-4000",5000:"4000-5000",18000:"> 5000"},inplace=True)

# %%
pivot_table_2
# Out:
# Extra Altitude Bins       <= 1000  1000-2000  2000-3000  3000-4000  4000-5000  \
# Effect: Indicated Damage
# Caused damage                8648       1534        468        155        129
# No damage                   49890       2382       1455        762        473
#
# Extra Altitude Bins       > 5000
# Effect: Indicated Damage
# Caused damage                388
# No damage                    964

# %%
plt.figure(figsize=(10,5))
sns.heatmap(pivot_table_2,annot=True,vmin=100,vmax=5000,fmt='g',cmap="YlGnBu")
plt.title("Number of Birds Strike Effect On Aicraft At Different Altitude",fontsize=20)
plt.xlabel("Altitude")
plt.ylabel("Indicated Damage")
plt.show()

# %% [markdown]
# From the above heatmap we can retrieve that as we see earlier more number of bird strikes occured at less altitude and now we see the damage is also
# done at <= 1000 altitude and by the altitude is increasing the damage on aircraft by birds strike is also also decreasing same case apply for the
# non damage done to aircraft by the birds strike so altitude is key factor playing in the damage as well

# %% [markdown]
# # Pilots informed? Prior Warning and effect of strike relation

# %%
df_1.columns
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Wildlife: Number struck', 'Wildlife: Number Struck Actual',
#        'Effect: Impact to flight', 'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Airline/Operator', 'Origin State', 'When: Phase of flight',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $', 'Altitude',
#        'Number of people injured', 'Is Aircraft Large?', 'Extra Altitude Bins',
#        'Year', 'month'],
#       dtype='object')

# %%
df_1["Pilot warned of birds or wildlife?"].unique()
# Out:
# array([0., 1.])

# %%
df_1["Pilot warned of birds or wildlife?"] = df_1["Pilot warned of birds or wildlife?"].replace({0:"Not Informed",1:"Informed"})

# %%
ax_1 = sns.countplot(data = df_1,x="Pilot warned of birds or wildlife?",palette="Oranges")
for x in ax_1.containers:
    ax_1.bar_label(x)
plt.xlabel("Pilot warned or not",fontsize=20)
plt.ylabel("Number of times",fontsize=20)
plt.title("Pilot warned or not about the birds distribution",fontsize=30)
plt.show()

# %% [markdown]
# From the above visuals we can retrieve that as equal distribution of warnings as many times pilot warned many times not but not informed is greater than
# informed because it is difficult for air controller to detect the birds in the sky as well

# %%
sns.catplot(data = df_1, x= "Effect: Indicated Damage",y="Wildlife: Number Struck Actual",col="Pilot warned of birds or wildlife?",kind="bar",
           estimator="sum",palette="PuBu",aspect=1)

plt.show()

# %% [markdown]
# From the above graph we can see that when the pilot are informed the birds strike impact less damage as compare to when pilot are not informed but the
# data above showing the all birds strike in both the informed and not informed and the distribution is nearly around same values that mean after
# informing the pilot the bird strike still done but the impact is not as per the when pilots are not informed and the difference between caused damage
# in both the cases is also not so big so pilots should be  provided with more trainings how to handle if you informed by the air controllers

# %%
df_1["Remains of wildlife collected?"].unique()
# Out:
# array([False,  True])

# %% [markdown]
# # How many times the remains of bird collected

# %%
ax_1 =sns.countplot(data = df_1,x="Remains of wildlife collected?")
for x in ax_1.containers:
    ax_1.bar_label(x)
plt.title("Times of birds remains collected by Air controllers",fontsize=20)
plt.ylabel("Number of times")
plt.show()

# %% [markdown]
# From the above graph we can see that many times the remains are not collected and yes it is difficult to find that also but we should work on the
# techniques on how to finding out the remains and sending to Smithsonian

# %%
ax_1 =sns.countplot(data = df_1,x="Remains of wildlife sent to Smithsonian")
for x in ax_1.containers:
    ax_1.bar_label(x)
plt.title("Times of birds remains sent to smithsonian by Air controllers",fontsize=20)
plt.ylabel("Number of times")
plt.show()

# %% [markdown]
# Above graph shows not the good results as per from the wildlife protector around very less times the remains are sent to smithsonian and air line
# operators should focus on how to increase this ratio
